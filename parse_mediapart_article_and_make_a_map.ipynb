# %% [markdown]
# # Parse Mediapart article to produce a map plot
#
# ## Article source
#
# https://www.mediapart.fr/journal/politique/020724/legislatives-la-galerie-des-candidats-rn-injustement-salis-selon-bardella?userid=d599962d-c199-4f52-af8b-3aca7df6b63b
#
# ## Temp file
# We cannot directly access this URL as it required a paid account.
# We save the HTML as a temp file bearing such name and path:
# `/content/Législatives _ la galerie des candidats RN injustement salis selon Bardella _ Mediapart.html`

# %% [markdown]
# ## install parser

# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib) (0.5.1)

# %% [markdown]
# ## parse local HTML file

# %%
from bs4 import BeautifulSoup

def parse_html(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    soup = BeautifulSoup(content, 'html5lib')

    data = []

    for li in soup.find_all('li', {'data-categories': True}):
        category = li['data-categories']
        img_tag = li.find('img')
        img_src = img_tag['src'] if img_tag else ''
        figcaption = li.find('figcaption')

        # Extracting the name
        name_tag = figcaption.find('strong')
        name = name_tag.text.strip() if name_tag else ''

        # Extracting the subtitle
        subtitle_tag = figcaption.find('p', class_='subtitle')
        subtitle = subtitle_tag.text.strip() if subtitle_tag else ''

        # Extracting the description
        description_tags = figcaption.find_all('p')
        description = ' '.join(p.text.strip() for p in description_tags[2:]) if len(description_tags) > 2 else ''

        data.append({
            'category': category,
            'image_src': img_src,
            'name': name,
            'subtitle': subtitle,
            'description': description
        })

    return data


# Example usage
file_path = '/content/Législatives _ la galerie des candidats RN injustement salis selon Bardella _ Mediapart.html'
parsed_data = parse_html(file_path)
for item in parsed_data:
    print(item)
# Out:
# {'category': 'Ain', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/mourey.jpg', 'name': 'Jean-Marie Mourey', 'subtitle': '1ère circonscription de l’Ain - 39,37\xa0% Suppléant', 'description': '« Vive la France, vive le roi\xa0!\xa0» Sur ses réseaux sociaux –\xa0aujourd’hui désactivés\xa0–, le candidat RN a longtemps partagé les publications de l’Action française (AF), mouvement royaliste dont il fut un responsable départemental pendant de nombreuses années. En 2019, Jean-Marie Mourey faisait part de son refus de participer aux élections, «\xa0ne pouvant cautionner cette République par [son] vote\xa0», associant la Révolution française au «\xa0vol\xa0», au «\xa0viol\xa0» et au «\xa0crime\xa0». Auprès de Mediapart, le candidat affirme avoir démissionné de l’AF en rejoignant le RN en 2022.'}
# {'category': 'Ain', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/buisson.jpg', 'name': 'Jérôme Buisson', 'subtitle': '4ème circonscription de l’Ain - 46,01\xa0% Sortant', 'description': 'À une déclaration du député noir Carlos Martens Bilongo, le député RN Jérôme Buisson a répondu le 13 mai 2024 sur son compte X\xa0: «\xa0Pour Bilongo, la France est un hall de gare, une salle d’attente woke, un Cada [centre d’accueil pour demandeurs d’asile –\xa0ndlr].\xa0» Dans un autre message, l’élu parle aussi des «\xa0enturbannés\xa0» pour décrire les musulmans. «\xa0Vous chipotez, cela ne me choque pas\xa0», a-t-il assumé auprès de Mediapart.'}
# {'category': 'Aisne', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/dessigny.jpg', 'name': 'Jocelyn Dessigny', 'subtitle': '5ème circonscription de l’Aisne - 53,07\xa0% Sortant Élu au premier tour', 'description': 'Sur son compte Facebook, le député et candidat dans l’Aisne Jocelyn Dessigny a posté une photo de lui avec un tee-shirt du groupe de rock identitaire In Memoriam, qui a notamment repris un chant de marche de la Jeunesse hitlérienne, La Colonne. Interrogé sur cette photo, l’élu n’a pas répondu.'}
# {'category': 'Allier', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/bovet.jpg', 'name': 'Jorys Bovet', 'subtitle': '2ème circonscription de l’Allier - 34,33\xa0% Sortant', 'description': 'Le député se saisit régulièrement de faits divers relayés par la fachosphère pour stigmatiser les étrangers. En réaction à une vidéo montrant des réfugiés dormant dans les couloirs du métro à Paris, Jorys Bovet écrit avec sarcasme en août 2023\xa0: «\xa0Notre “chance pour la France”.\xa0» En décembre 2023, réagissant à l’agression d’une élue PS à Saint-Denis, il commente\xa0: «\xa0Ou quand le “bien vivre ensemble” te rencontre.\xa0» Il est depuis établi que l’agression a été commanditée par un chef d’entreprise mécontent de ne pas avoir obtenu un marché public.'}
# {'category': 'Alpes-Maritimes', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/tivoli.jpg', 'name': 'Lionel Tivoli', 'subtitle': '2ème circonscription des Alpes-Maritimes - 48,08\xa0% Sortant', 'description': 'Si Lionel Tivoli fait désormais campagne avec Éric Ciotti dans les Alpes-Maritimes, les deux hommes n’ont pas toujours été sur la même ligne. En novembre 2022, tandis que le patron du parti Les républicains (LR) dénonce les «\xa0propos d’une extrême gravité\xa0» du RN Grégoire de Fournas adressés au député Carlos Martens Bilongo (« Qu’il retourne en Afrique\xa0»), Lionel Tivoli interpelle son collègue sur X\xa0: «\xa0Pourquoi\xa0? Vous ne voulez pas que les clandestins retournent en Afrique\xa0?\xa0» En janvier 2024, il déclare que «\xa0partout où [les mineurs isolés] passent, ces derniers dealent, agressent et pourrissent la vie des riverains\xa0».'}
# {'category': 'Alpes-Maritimes', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/orabana.jpg', 'name': 'Andrea Orabona', 'subtitle': '2ème circonscription des Alpes-Maritimes - 48,08\xa0% Suppléant', 'description': 'Sur Facebook, il a «\xa0liké\xa0» un «\xa0hommage au maréchal Pétain\xa0» et la page du «\xa0Front des patriotes\xa0», qui célèbre le suprémacisme blanc. Son nom a disparu de la liste quand Libération a enquêté dessus.'}
# {'category': 'Alpes-Maritimes', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/masson.jpg', 'name': 'Bryan Masson', 'subtitle': '6ème circonscription des Alpes-Maritimes - 50,85\xa0% Sortant Élu au premier tour', 'description': 'À la suite de la mort de trois hommes –\xa0Manuolito, Ismaël et Atama\xa0–, tués à Angers en juillet 2022 par un ressortissant soudanais en état d’ébriété, le député écrit sur X\xa0: «\xa0Angers est le reflet de la France. Trois jeunes ont été assassinés hier soir par un Soudanais. La sauvagerie s’étend partout sur le territoire et les criminels étrangers prospèrent.\xa0» Les avocats des familles de victimes dénoncent la «\xa0récupération politique\xa0» du drame.'}
# {'category': 'Ardèche', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/dussud.jpg', 'name': 'Thierry Dussud', 'subtitle': '2ème circonscription des l’Ardèche - 35,75\xa0% Suppléant', 'description': '« Rendons les Africains à l’Afrique\xa0»\xa0; «\xa0Omar Sy, si tu pouvais rester aux US, c’est mieux pour toi et pour nous, les nationalistes\xa0»\xa0; «\xa0Je suis pour le regroupement familial… d’Alger au Cap\xa0»… Thierry Dussud a supprimé sa page Facebook après la publication de plusieurs de ses messages par Libération. Le candidat titulaire dit avoir «\xa0découvert avec stupeur les propos tenus\xa0» par son suppléant.'}
# {'category': 'Aube', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/arbona.jpg', 'name': 'Philippe Arbona', 'subtitle': '2ème circonscription de l’Aube - 44,83\xa0% Suppléant', 'description': 'Visiblement nostalgique du mouvement néofasciste Ordre nouveau dissous en 1973 pour sa violence puisqu’en 2020, il postait un de leurs anciens tracts avec comme commentaire\xa0: «\xa0Aujourd’hui l’anarchie, demain l’ordre nouveau.\xa0»'}
# {'category': 'Bouches-du-Rhône', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/griset.jpg', 'name': 'Monique Griseti', 'subtitle': '1ère circonscription des Bouches-du-Rhône - 45,54\xa0%', 'description': 'La Provence a relevé plusieurs de ses saillies\xa0: «\xa0Qu’il retourne de là où il vient\xa0», «\xa0Qu’il aille traire la chèvre, ça nous fera des vacances\xa0» ou encore\xa0: «\xa0Qu’est-ce qu’on attend pour les mettre dans un avion, ces moins que rien.\xa0» Elle a aussi recommandé le film Sound of Freedom, un pseudo-documentaire américain relayant nombre de théories de la mouvance QAnon.'}
# {'category': 'Bouches-du-Rhône', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/melin.jpg', 'name': 'Joëlle Mélin', 'subtitle': '9ème circonscription des Bouches-du-Rhône - 45,20\xa0%', 'description': 'Médecin de formation, Joëlle Mélin déclare en mai 2024, à la suite de la mort d’un enfant de 3 ans du choléra à Mayotte, qu’il est «\xa0impossible de nier que les cas de choléra sur l’île ne soient pas en relation directe avec l’immigration clandestine venue des grands lacs africains, entièrement gérée par des comoriens\xa0!\xa0». Un an plus tôt, elle dénonçait le succès d’une structure d’accueil de réfugiés dans les colonnes de La Provence\xa0: «\xa0Je reste opposée à ce centre. Entendons-nous bien\xa0: je suis pour un accueil dans la dignité, mais contre le fait de les prévenir de leur expulsion, ce qui leur laisse tout loisir de partir. Je les préfère cent fois à Djibouti, ils sont mieux dans leur milieu naturel [sic].\xa0»'}
# {'category': 'Calvados', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/daoudi.jpg', 'name': 'Ludivine Daoudi', 'subtitle': '1ère circonscription du Calvados - 19,95\xa0%', 'description': 'Sa candidature a finalement été retirée à la suite de la publication, au lendemain de son score important au premier tour, d’une photo d’elle avec une casquette nazie. Absente pendant toute la campagne, Ludivine Daoudi est aussi membre du Parti de la France, mouvement pétainiste avec lequel le RN est censé avoir pris ses distances, ainsi que l’a révélé StreetPress.'}
# {'category': 'Calvados', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/liban.jpg', 'name': 'Josseline Liban', 'subtitle': '2ème circonscription du Calvados - 25,84\xa0%', 'description': 'Dans la circonscription voisine de Ludivine Daoudi, la candidate RN a, elle aussi, multiplié les publications racistes sur les réseaux sociaux, comme l’a dénoncé son adversaire, le sortant socialiste Arthur Delaporte. En plus de partages de contenus complotistes sur la vaccination, elle a aussi partagé une publication sous-entendant que les personnes noires ne peuvent pas être françaises.'}
# {'category': 'Calvados', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/chapron.jpg', 'name': 'Philippe Chapron', 'subtitle': '5ème circonscription du Calvados - 31,86\xa0%', 'description': 'Militant de la première heure au Front national, Philippe Chapron apparaît dans un rapport sénatorial sur le service d’ordre (DPS) du parti d’extrême droite en 1999, où il est cité comme faisant partie des «\xa0îlots activistes et pro-nazis au sein de certains groupes locaux\xa0». En 1993, dans une voiture appartenant à Philippe Chapron, la police découvre un fléau japonais, un poing américain, un pistolet lance-fusées calibre 12 et des balles en caoutchouc, un sabre d’exercice japonais en bois ainsi que 26 manches de pioche. Vingt ans plus tard, Philippe Chapron assume à la télévision son passé dans les rangs d’Ordre nouveau, groupuscule néofasciste.'}
# {'category': 'Cher', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/gentillet.jpg', 'name': 'Pierre Gentillet', 'subtitle': '3ème circonscription du Cher - 43,15\xa0%', 'description': 'L’avocat Pierre Gentillet est le fondateur du Cercle Pouchkine, un think tank pro-Poutine créé en 2015. Le chroniqueur régulier de CNews a continué, après 2022, à défendre les intérêts russes. Il a jugé que l’invasion de l’Ukraine était «\xa0préventive\xa0» et a dit «\xa0comprendre Vladimir Poutine\xa0». Par la suite, il a émis des doutes sur la responsabilité des Russes dans le massacre de Boutcha en Ukraine et a estimé que, s’agissant de la «\xa0guerre civile en Ukraine\xa0», les Français étaient «\xa0bien moins intoxiqués par la propagande russe qu’occidentale\xa0».'}
# {'category': 'Cher', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/apricena.jpg', 'name': 'Julie Apricena', 'subtitle': '3ème circonscription du Cher - 43,15\xa0% Suppléante', 'description': 'Cette membre du bureau national du RN est une militante bien connue dans le département du Cher, où elle défend les idées de Marine Le Pen depuis son plus jeune âge. Candidate suppléante, elle a été identifiée sur des photos récupérées par le site La Horde en compagnie de militants identitaires ou portant un tee-shirt suprémaciste\xa0: «\xa0White pride, world wide\xa0». Contactée par Mediapart, elle a répondu\xa0: «\xa0J’avais 16 ans, je ne savais pas ce que je faisais. Je n’avais pas connaissance de la portée politique de ce symbole.\xa0»'}
# {'category': 'Corrèze', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/pouget.jpg', 'name': 'Maïtey Pouget', 'subtitle': '1ère circonscription de Corrèze - 30,89\xa0%', 'description': 'En campagne, elle déclare\xa0: «\xa0On est envahis par les migrants\xa0!\xa0» Le journaliste montre le marché autour d’eux et lui répond\xa0: «\xa0Bah non.\xa0» La candidate reprend\xa0: «\xa0Mais c’est parce qu’à cette heure là ils dorment\xa0!\xa0»'}
# {'category': 'Corrèze', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/03/elophe.jpg', 'name': 'Valéry Élophe', 'subtitle': '2ème circonscription de Corrèze - 36,28\xa0%', 'description': 'Le secrétaire départemental du Rassemblement national a accusé, après les atrocités du 7 octobre, la CFDT, la CGT, la FSU et FO d’être «\xa0les idiots utiles et collabos des terroristes du Hamas\xa0». «\xa0Espérons qu’un jour, ils sortent épuisés d’être dans la malveillance et la haine des juifs\xa0»,\xa0a ajouté le militant,\xa0au FN-RN depuis 2012.'}
# {'category': 'Côte-d’Or', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/dumont.jpg', 'name': 'Sophie Dumont', 'subtitle': '4ème circonscription de Côte-d’Or - 42,33\xa0%', 'description': 'Comme l’a relevé Libération, la candidate partageait le 19 mars 2024 des propos de l’ancien eurodéputé néerlandais Marcel de Graaff décrivant l’Ukraine comme «\xa0le plus grand fournisseur d’enfants pour les réseaux pédophiles\xa0». La candidate est aussi adepte de la feuille antisémite Faits & documents, dont elle aime à relayer l’un des complots préférés\xa0: Brigitte Macron serait un homme.'}
# {'category': 'Côte-d’Or', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/lioret.jpg', 'name': 'René Lioret', 'subtitle': "5ème circonscription de Côte-d'Or - 45,31\xa0%", 'description': 'Son élection au conseil régional de Bourgogne-Franche-Comté en juin 2021 n’a pas inhibé René Lioret. Sur son compte X, cet ancien cadre d’un laboratoire pharmaceutique déclarait, par exemple, en réaction à la diffusion d’images d’un passage à tabac d’un jeune handicapé par d’autres adolescents, en octobre 2022\xa0: «\xa0Les racailles africaines, c’est toujours à 3 ou 4 contre 1. C’est à ça qu’on les reconnaît\xa0!\xa0» En juin 2023, l’élu réagissait à un post sur le prétendu massacre d’un chameau en Afrique avec cet autre message\xa0: «\xa0Aucun doute n’est possible\xa0! Nous avons bien à faire à des barbares. Si l’UE [Union européenne – ndlr] compte sur “ça” pour repeupler le Vieux Continent…\xa0»'}
# {'category': 'Côtes-d’Armor', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/02/billaud.jpg', 'name': 'Françoise Billaud', 'subtitle': '1ère circonscription des Côtes-d’Armor - 25,75\xa0%', 'description': 'En pleine campagne, la candidate s’est tout d’un coup volatilisée, annulant toutes ses interviews et supprimant ses comptes sur les réseaux sociaux. Françoise Billaud y postait depuis plusieurs années des messages homophobes, transphobes, racistes ou véhiculant les pires clichés antisémites. Comme cette affiche du dictateur, avec une photographie d’Emmanuel Macron, «\xa0film de Jacques Attali produit par George Soros\xa0».'}
# {'category': 'Côtes-d’Armor', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/lude.jpg', 'name': 'Noël Lude', 'subtitle': '4ème circonscription des Côtes-d’Armor - 34,30\xa0%', 'description': 'Voici un fan de dessins et caricatures racistes, qu’il n’hésite pas à relayer sur les réseaux sociaux, comme celle\xa0 décrivant la CAF comme le «\xa0troisième lieu saint de l’islam\xa0».'}
# {'category': 'Côtes-d’Armor', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/03/boulanger.jpg', 'name': 'Jean-Yves Le Boulanger', 'subtitle': '5ème circonscription des Côtes-d’Armor – 29,08\xa0%', 'description': 'Quand on\xa0«\xa0le traite de facho\xa0», cela fait\xa0«\xa0un peu sourire\xa0»\xa0Jean-Yves Le Boulanger. Ce candidat, travaillant dans le bâtiment et l’immobilier, encarté depuis six ans au RN, a expliqué pourquoi dans un\xa0entretien\xa0accordé le 18 juin\xa0:\xa0«\xa0J’ai des amis qui viennent du milieu islamique, et il n’y a jamais de souci. Et j’ai des très bons amis de couleur.\xa0»\xa0Le possible futur député assure (et semble se réjouir) que\xa0« les Asiatiques, on ne les entend jamais ». Pour démontrer sa bonne foi, il convoque une anecdote :\xa0« Pas plus tard que dimanche, je suis allé à un rassemblement de motards […] et c’est un curé de couleur qui m’a béni. Vous voyez, je ne l’ai pas écrasé avec ma moto ! »'}
# {'category': 'Dordogne', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn
 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/meizonnet.jpg', 'name': 'Nicolas Meizonnet', 'subtitle': '2ème circonscription du Gard - 52,22\xa0% Sortant Élu au premier tour', 'description': 'Sur X, il n’hésite pas à extrapoler à partir de tout fait divers impliquant un étranger ou un Français ayant un nom d’origine étrangère\xa0: «\xa0Ils sont Français, mais pas un seul n’a un nom à consonance française. Cela ne surprendra personne\xa0»\xa0; «\xa0Encore combien de Françaises violées faudra-t-il pour que ce gouvernement expulse de notre pays tous les clandestins et les étrangers sous OQTF\xa0?\xa0»\xa0; «\xa0Il faudra bien un jour que ceux qui organisent l’invasion migratoire répondent de leurs actes. Immense colère de voir tant de jeunes Français massacrés par des barbares\xa0».'}
# {'category': 'Gard', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/bordes.jpg', 'name': 'Pascale Bordes', 'subtitle': '2ème circonscription du Gard - 47,48\xa0% Sortante', 'description': 'Quand elle parle du burkini, qu’elle estime être «\xa0un très grand danger\xa0», elle pense au nazisme et convoque Bertold Brecht\xa0: «\xa0Celui qui ne sait pas est un imbécile, mais celui qui sait et ne fait rien est un criminel.\xa0» Elle ajoute\xa0: «\xa0Je dis que celui qui sait et ne dit rien ni ne fait rien est un criminel.\xa0»'}
# {'category': 'Haute-Garonne', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/khalifa.jpg', 'name': 'Frank Khalifa', 'subtitle': '2ème circonscription de Haute-Garonne - 26,41\xa0%', 'description': 'Quand le représentant de Reporter sans frontières (RSF) Christophe Deloire, depuis décédé, demande à\u200b\u200b l’Arcom de revoir les règles de contrôle de CNews et Bolloré, le candidat RN s’écrie le 21 février 2024\xa0: «\xa0Le retour du pétainiste\xa0!\xa0» Trois jours plus tard, il affirme que les «\xa030\xa0000 Palestiniens et Palestiniennes assassinés par l’armée israélienne\xa0» sont «\xa030\xa0000 terroristes\xa0».'}
# {'category': 'Haute-Garonne', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/alarcon.jpg', 'name': 'Stéphanie Alarcon', 'subtitle': '3ème circonscription de Haute-Garonne - 21,38\xa0%', 'description': 'La candidate a perdu tout espoir\xa0: «\xa0Tout ça finira mal un jour ou l’autre, ils ne sont pas assimilés et ils ne le seront jamais.\xa0» Elle estime aussi que l’Ukraine, qui aurait en réalité déclenché la guerre, «\xa0alimente aujourd’hui le marché et la vente d’organes pour financer sa guerre avec l’aval des US, de l’Otan et l’Europe\xa0».'}
# {'category': 'Gironde', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/chadourne.jpg', 'name': 'Sandrine Chadourne', 'subtitle': '10ème circonscription de Gironde - 43,80\xa0%', 'description': 'Sur Facebook, elle a notamment partagé, comme l’a repéré Libération, l’image d’une vieille dame penchée au-dessus d’une poubelle avec ce commentaire mensonger\xa0: «\xa0C’est honteux. Pendant que nos retraités font les poubelles, les immigrés, eux, touchent une retraite à taux plein sans jamais avoir cotisé.\xa0»'}
# {'category': 'Ille-et-Vilaine', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/mareschi.jpg', 'name': 'Jean-Pierre Mareschi', 'subtitle': '5ème circonscription d’Ille-et-Vilaine - 29,82\xa0% Suppléant', 'description': 'Il compare, photo à l’appui, l’équipe de France de football à une «\xa0équipe africaine\xa0», multiplie les blagues homophobes et présente les gens du voyage comme intrinsèquement voleurs de cuivre.'}
# {'category': 'Ille-et-Vilaine', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/03/lemoine.jpg', 'name': 'Dylan Lemoine', 'subtitle': '7ème circonscription d’Ille-et-Vilaine - 28,20\xa0%', 'description': 'Dylan Lemoine connaît son territoire. « J’ai fait du porte à porte, j’ai été sur les marchés à Dol. Chacun nous a dit que l’insécurité n’avait cessé d’augmenter depuis l’ouverture de ce centre », a-t-il expliqué au cours d’un débat contre ses adversaires. Le candidat du RN faisait référence à l’ouverture d’un centre pour mineurs étrangers, contre lequel il a accès sa campagne. Lequel centre n’a en réalité pas encore ouvert ses portes.'}
# {'category': 'Indre', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/02/wunsch.jpg', 'name': 'Mylène Wunsch', 'subtitle': '1ère circonscription de l’Indre - 40,20\xa0%', 'description': "Mylène Wunsch n’aime pas La France insoumise (LFI) –\xa0qu’elle estime «\xa0soumise\xa0» à l’islam – en général, et la députée Danièle Obono en particulier. «\xa0Quelle morue\xa0!!! Et je m'excuse pour les morues [émoji clin d’œil]\xa0», écrit-elle en octobre 2022 en réaction à un interview de la députée de Paris."}
# {'category': 'Indre-et-Loire', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/fougeron.jpg', 'name': 'Corine Fougeron', 'subtitle': '2ème circonscription d’Indre-et-Loire - 35,08\xa0%', 'description': 'Arrivée en tête dans sa circonscription, cette candidate a relayé sur Facebook une vidéo complotiste titrée « La mafia maçonnique qui tient la France\xa0», qui accuse Emmanuel Macron d’être à la solde, au choix, du groupe Bilderberg, de Rothschild ou des francs-maçons. Interrogée par Libération, qui a repéré la publication, elle s’était défendue en expliquant vouloir «\xa0montrer à [ses] followers ce qui se passe sur les réseaux\xa0» et «\xa0être opposée aux dires de cette vidéo\xa0».'}
# {'category': 'Jura', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/mosca.jpg', 'name': 'Thierry Mosca', 'subtitle': '2ème circonscription du Jura - 32,76\xa0%', 'description': 'Sa candidature a été validée par les services préfectoraux alors qu’il est placé sous curatelle renforcée depuis novembre 2023, et donc inéligible, selon les informations de Mediapart. La justice a confié à un tiers le soin de l’assister dans ses démarches courantes, jusqu’à la gestion de ses comptes bancaires et de ses moindres dépenses. Interrogé par nos soins, il a préféré mentir en assurant qu’il s’agissait d’«\xa0un problème d’homonymie\xa0» avec quelqu’un qui aurait «\xa0le même nom et le même prénom\xa0».'}
# {'category': 'Landes', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/biesbrouck.jpg', 'name': 'Ludovic Biesbrouck', 'subtitle': '2ème circonscription des Landes - 32,60\xa0%', 'description': 'En août 2023, alors que les recherches sur les auteurs d’une agression mortelle aux fêtes de Bayonne débutent à peine, cet agent de sécurité landais tire déjà ses propres conclusions sur X\xa0: «\xa0Nos fêtes ont été souillées par des barbares. 3 personnes de type Méditerranéen [sic]\xa0!! La police est toujours à la recherche de cet individu qui a tué gratuitement un Bayonnais lors des fêtes de Bayonne. Réveillez vous [émojis drapeau français].\xa0»'}
# {'category': 'Loir-et-Cher', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/chudeau.jpg', 'name': 'Roger Chudeau', 'subtitle': '2ème circonscription du Loir-et-Cher - 49,72\xa0%', 'description': 'Celui qui estime que vu sa binationalité, Najat Vallaud-Belkacem n’aurait jamais dû être ministre, considère que l’école française sera «\xa0bientôt une école de type arabo-musulman avec des petits bouts de charia\xa0». Ses réflexions ont aussi des relents transphobes\xa0: «\xa0Vous pouvez dire\xa0: “Je suis une girafe”, on est chez les fous\xa0!\xa0»'}
# {'category': 'Loire', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/03/rambaud.jpg', 'name': 'Gerbert Rambaud', 'subtitle': '4ème circonscription de la Loire - 40,80\xa0%', 'description': 'Très actif sur les réseaux sociaux, le candidat RN a deux obsessions : les homosexuels et Georges Soros, ce milliardaire juif américain devenu\xa0l’ennemi public numéro un\xa0de l’extrême droite.\xa0Les messages de Gerbert Rambaud, repérés par le compte Le coin des LGBT+, ciblent Soros, accusé de financer le «\xa0lobby LGBT\xa0». Dans Le Progrès, le candidat se justifie en expliquant que « les LGBT ont des actions au sujet du transsexualisme vis-à-vis des écoles et des enfants ».'}
# {'category': 'Loire', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/lucas.jpg', 'name': 'Michel Lucas', 'subtitle': '5ème circonscription de la Loire - 36,09\xa0% Suppléant', 'description': 'Le patron du RN dans la Loire relaie tranquillement les messages d’un groupe intitulé «\xa0Conseil représentatif des associations blanches de France\xa0», qui assure dans sa description\xa0: «\xa0Depuis plus de 2000 ans, la France est blanche. Depuis 40 ans, elle devient grise et noire.\xa0»\xa0En 2019, comme l’avait raconté Le Parisien, il n’avait pas eu besoin de relayer qui que ce soit pour expliquer voir dans la «\xa0volonté d’islamisation de la France par notre gouvernement […]\xa0 un génocide masqué\xa0».'}
# {'category': 'Loire-Atlantique', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/comby.jpg', 'name': 'Bruno Comby', 'subtitle': '5ème circonscription de Loire-Atlantique - 24,73\xa0%', 'description': 'Deux de ses ouvrages ont été préfacés par Henri Joyeux, qui a été interdit d’exercer la médecine pour ses déclarations fallacieuses contre des vaccins. Il a surtout écrit un livre dans lequel il explique que le crudivorisme (pratique alimentaire qui consiste à se nourrir exclusivement d’aliments crus) permet de mieux se protéger contre le sida.'}
# {'category': 'Loiret', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/zeller.jpg', 'name': 'Anthony Zeller', 'subtitle': '6ème circonscription du Loiret - 31,81\xa0%', 'description': 'Candidat arrivé en tête dans sa circonscription, Anthony Zeller avait demandé, en 2022, à l’élue de LFI Mathilde Panot où avait été prise une photo qu’elle avait postée depuis sa circonscription, feignant de s’interroger\xa0: «\xa0C’est où\xa0? En Afrique\xa0?\xa0» Après la révélation de ces propos par Libération, son adversaire sur la circonscription, l’ex-député MoDem Richard Ramos, a annoncé porter plainte.'}
# {'category': 'Loiret', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/templier.jpg', 'name': 'Jean-Pierre Templier', 'subtitle': '6ème circonscription du Loiret - 31,81\xa0% Suppléant', 'description': 'Suppléant d’Anthony Zeller, Jean-Pierre Templier n’est pas en reste. Ses propos sexistes sur Valérie Hayer pendant la campagne européenne côtoient, sur ses réseaux sociaux, des vieux posts aux relents antisémites, comme lorsqu’il dénonçait\xa0: «\xa0Cette communauté nous dirige, combien sont au gouvernement, à la tête des entreprises du CAC 40\xa0?\xa0»'}
# {'category': 'Maine-et-Loire', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn
 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/martin.jpg', 'name': 'Joseph Martin', 'subtitle': '1ère circonscription du Morbihan - 25,37\xa0%', 'description': 'Le RN avait d’abord annoncé ne plus accorder son investiture avant de le réinvestir. La faute à un message aux relents antisémites\xa0: en octobre 2018, le candidat RN avait écrit sur X que «\xa0le gaz a rendu justice aux victimes de la Shoah\xa0». Joseph Martin s’est défendu en jurant qu’il réagissait à l’époque à la mort du négationniste Robert Faurisson et qu’il fallait donc voir là «\xa0un hommage aux victimes de la Shoah\xa0». Il ne s’est pas exprimé sur les autres tweets racistes qu’il a signés sur X.'}
# {'category': 'Morbihan', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/kersauson.jpg', 'name': 'Florent de Kersauson', 'subtitle': '2ème circonscription du Morbihan - 30,03\xa0%', 'description': 'Conseiller régional de Bretagne et frère du célèbre navigateur, Florent de Kersauson devait être jugé le 12 juin pour abus de confiance et abus de biens sociaux, pour avoir floué les souscripteurs de son fonds d’investissement (il a déjà été condamné pour des faits similaires). Le jour du procès, il se fait porter pâle, au grand dam des petits épargnants s’étant constitués parties civiles. Miracle de la médecine, il est suffisamment rétabli pour être investi le jour même par son parti pour les législatives. L’élu a aussi partagé en janvier un post\xa0qualifiant de «\xa0faux Breton\xa0» un enfant métis arborant le drapeau de la Bretagne en couverture du magazine Le Peuple breton.'}
# {'category': 'Morbihan', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/02/renard.jpg', 'name': 'Gregory Renard', 'subtitle': '2ème circonscription du Morbihan - 31,51\xa0% Suppléant', 'description': 'Suppléant, Gregory Renard se cache à peine sur X pour déverser son racisme. Sous le pseudo «\xa0GregduMorbihan\xa0», il emploie à satiété le terme de «\xa0bogmoule\xa0», substitut de l’insulte raciste «\xa0bougnoule\xa0» destiné à éviter la censure des réseaux sociaux. Son autre obsession a pour nom Brigitte Macron, qu’il qualifie à chaque fois qu’il le peut de pédophile (il relaie également les mèmes reprenant la théorie complotiste suivant laquelle la première dame serait en fait un homme).'}
# {'category': 'Moselle', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/03/jacobelli.jpg', 'name': 'Laurent Jacobelli', 'subtitle': '8ème circonscription de Moselle - 46,36\xa0% Sortant', 'description': '«\xa0Joue pas ta racaille.\xa0» C’est en ces termes que le porte-parole du RN s’en est pris au député Renaissance Belkhir Belhaddad au cours d’une cérémonie le 13 octobre 2023. « Tu me parles autrement, je te le dis tout de suite. Racaille », lui a-t-il\xa0aussi lancé,\xa0en lui demandant : «\xa0Il va bien le Hamas ?\xa0»'}
# {'category': 'Pyrénées-Atlantiques', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/becker.jpg', 'name': 'Monique Becker', 'subtitle': '2ème circonscription des Pyrénées-Atlantiques - 31,14\xa0%', 'description': 'Nostalgique du dictateur Franco et de l’OAS, Monique Becker relaie aussi sur son compte Facebook un projet de «\xa0remigration\xa0», ce projet secret de l’extrême droite allemande contre lequel ont manifesté des centaines de milliers de personnes au printemps.'}
# {'category': 'Pyrénées-Atlantiques', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/02/lopez.jpg', 'name': 'Sylviane Lopez', 'subtitle': '4ème circonscription des Pyrénées-Atlantiques - 25,62\xa0%', 'description': 'Au chroniqueur Gilles Verdez qui se félicite du déboulonnage d’une statue de l’esclavagiste Léopold II, elle suggère d’«\xa0aller [se] présenter aux élections d’un quelconque pays d’Afrique\xa0». À un détracteur de Marine Le Pen, elle répond aussi\xa0: «\xa0Dommage que vous n’alliez pas au moins une seule fois à un de ses meetings elle dit haut et clair [qu’il faut] faire des efforts pour développer l’Afrique et leur apporter la modernité.\xa0»'}
# {'category': 'Hautes-Pyrénées', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/sorin.jpg', 'name': 'Marie-Christine Sorin', 'subtitle': '1ère circonscription des Hautes-Pyrénées - 34,09\xa0%', 'description': 'Selon cette candidate, «\xa0non toutes les civilisations ne se valent pas\xa0». Certaines «\xa0sont juste restées au-dessous de la bestialité dans la chaîne de l’évolution\xa0», selon un tweet exhumé par Libération. S’en prenant à la porte-parole du gouvernement, Prisca Thevenot, elle se plaint sur X\xa0: «\xa0Si on lui dit de retourner sur son île on va être taxé de racisme.\xa0» Prisca Thevenot est d’origine mauricienne. Elle est née à Strasbourg.'}
# {'category': 'Hautes-Pyrénées', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/02/monteil-1.jpg', 'name': 'Olivier Monteil', 'subtitle': '2ème circonscription des Hautes-Pyrénées - 36,96\xa0%', 'description': "Le recteur de la Grande Mosquée de Paris a «\xa0invité\xa0» les musulmans à barrer la route à l’extrême droite lors des élections européennes. Ce qui n’a pas plus à Olivier Monteil. Message du candidat RN\xa0: «\xa0Nous on l’invite à prendre un billet d'avion et à aller en Arabie saoudite voir si on y est. Aller simple bien sûr.\xa0» Avocat franco-algérien, le recteur Chems-Eddine Hafiz est inscrit au barreau de Paris depuis 1991. Interrogé par Mediapart, Olivier Monteil assure que son message n’est «\xa0pas islamophobe\xa0» mais «\xa0anti-islamiste\xa0». Il tient à préciser\xa0: «\xa0Je l’invite [le recteur] à se rendre non pas dans son pays d'origine (auquel je ne me réfère aucunement) mais dans le pays le plus islamiste du monde, l’Arabie saoudite, qui pratique la charia. J’invite d'ailleurs tous les islamistes de France à prendre le même chemin.\xa0»"}
# {'category': 'Haut-Rhin', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/aubert.jpg', 'name': 'Nathalie Aubert', 'subtitle': '2ème circonscription du Haut-Rhin - 36,17\xa0%', 'description': 'Il arrive à cette candidate, selon Libération, de relayer des posts ouvertement racistes sur Facebook, comme, le 3 juin 2023, un montage juxtaposant la couverture de l’album Tintin au Congo et la photo d’une embarcation pleine à ras bord de migrants noirs. Légende\xa0: «\xa0Le Congo chez Tintin\xa0». Nathalie Aubert a ajouté un émoji hilare.'}
# {'category': 'Savoie', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/bernard.jpg', 'name': 'Brice Bernard', 'subtitle': '4ème circonscription de Savoie - 30,31\xa0%', 'description': 'En 2013, il s’est fait photographier effectuant une «\xa0quenelle\xa0». Un geste «\xa0antisystème\xa0» popularisé par l’humoriste antisémite Dieudonné. Sur une autre photo, il imite une personne asiatique. Il a répondu à StreetPress que ce devait être un montage.'}
# {'category': 'Seine-et-Marne', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/dimitrova.jpg', 'name': 'Ivanka Dimitrova', 'subtitle': '2ème circonscription de Seine-et-Marne - 35,06\xa0%', 'description': 'Sur ces réseaux sociaux, cette candidate arrivée en tête au premier tour est obsédée par l’Afrique. Après les propos du député Grégoire de Fournas à l’adresse du député noir LFI Carlos Bilongo, elle se demandait ainsi «\xa0si ce Parlement est français ou africain\xa0». Elle est également climatosceptique, considérant le réchauffement climatique comme «\xa0hypothétique\xa0».'}
# {'category': 'Seine-et-Marne', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/02/robin.jpg', 'name': 'Teddy Robin', 'subtitle': '8ème circonscription de Seine-et-Marne - 27,97\xa0% Suppléant', 'description': 'Teddy Robin utilise son compte X pour multiplier les attaques sexistes contre les représentantes politiques. «\xa0Hystérique\xa0» pour la députée écologiste Sandrine Rousseau, «\xa0hystérique la momone\xa0» (sic) à destination d’une autre élue insoumise, ou «\xa0bichette\xa0» pour la ministre Aurore Bergé – un terme «\xa0ironique et affectif\xa0» se justifie-t-il auprès de Mediapart. À la suite d’un homicide au Mans, il déclare aussi\xa0: «\xa0Quel politique peut encore défendre cette immigration incontrôlable et avec des mœurs du Moyen Âge\xa0? Quand ils ne violent pas ils tuent ou donnent des coups de couteaux. Pauvre France.\xa0» Interrogé par Mediapart, il se défend de tout sexisme et de toute xénophobie en jugeant qu’il s’agit d’une «\xa0interprétation\xa0» erronée de ses propos.'}
# {'category': 'Yvelines', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/brault.jpg', 'name': 'Gaëtan Brault', 'subtitle': '2ème circonscription des Yvelines - 21,81\xa0%', 'description': 'Sur son ancien compte X, le candidat du RN dans les Yvelines relayait abondamment les publications de la branche provençale de l’Action française, groupuscule royaliste qui rend régulièrement hommage à Charles Maurras.'}
# {'category': 'Deux-Sèvres', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/03/champeau.jpg', 'name': 'Dorothée Champeau', 'subtitle': '1ère circonscription des Deux-Sèvres - 24,62\xa0%', 'description': '«\xa0Très satisfaite\xa0» de son score au premier tour, Dorothée Champeau a voulu rassurer les électeurs auprès de La Nouvelle République au soir des résultats : « Beaucoup croient que tous les noirs vont rentrer chez eux alors que ceux qui travaillent, on ne va pas les renvoyer chez eux. »\xa0Après le tollé provoqué par ses propos, la candidate a accusé la presse d’avoir\xa0déformé ses paroles.'}
# {'category': 'Deux-Sèvres', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/guibert.jpg', 'name': 'Olivier Guibert', 'subtitle': '3ème circonscription des Deux-Sèvres - 35,23\xa0% Suppléant', 'description': 'Suppléant de Philippe Robin, candidat de l’alliance Ciotti-RN arrivé en tête dans les Deux-Sèvres, Olivier Guibert «\xa0aimait\xa0» de nombreuses pages Facebook. Parmi elles, d’après Le Nouvel Obs, «\xa0Poutine fan club\xa0» qui met en avant des figures de l’extrême droite radicale comme Alexandre Gabriac, militant néofasciste et ancien conseiller régional FN, exclu en 2011 après un salut nazi.'}
# {'category': 'Var', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/lottiaux.jpg', 'name': 'Philippe Lottiaux', 'subtitle': '4ème circonscription du Var - 56,11\xa0% Sortant Élu au premier tour', 'description': 'Député du Var depuis 2022, l’ancien directeur général des services de Patrick Balkany a été réélu dès le premier tour avec 56\xa0% des voix. Il est aussi un habitué des publications racistes sur les réseaux sociaux. En 2023, il partageait un post du site d’extrême droite Fdesouche en ironisant sur le «\xa0merveilleux apports des migrants, des racailles et des dealers\xa0» à Marseille. Quelques semaines plus tôt, réagissant à la mort d’Enzo, poignardé dans l’Eure, il fustigeait «\xa0la racaille décomplexée, fruit pourri de la culture de l’excuse, du laxisme judiciaire et de la submersion\xa0».'}
# {'category': 'Var', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/schreck.jpg', 'name': 'Philippe Schreck', 'subtitle': '8ème circonscription du Var - 53,55\xa0% Sortant Élu au premier tour', 'description': 'Lui aussi député sortant du Var et réélu dès le premier tour, Philippe Schreck était également monté au soutien de son collègue Grégoire de Fournas, en assumant\xa0: «\xa0Oui les migrants et les associations de passeurs subventionnés doivent retourner en Afrique.\xa0»'}
# {'category': 'Vienne', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/darles.jpg', 'name': 'Emmanuelle Darles', 'subtitle': '1ère circonscription de la Vienne - 28,93\xa0%', 'description': '«\xa0Scientifique engagée\xa0», Emmanuelle Darles est surtout une figure des mouvements antivax et complotistes. Elle a déjà assimilé la vaccination des enfants à «\xa0un viol\xa0» et est une habituée des émissions de «\xa0réinformation\xa0» autour du covid. La chercheuse est aussi membre du Conseil scientifique indépendant, association créée par Xavier Azalbert, dirigeant du site complotiste France-Soir, et par Réinfo covid, du médecin conspirationniste Louis Fouché.'}
# {'category': 'Yonne', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/02/grenon.jpg', 'name': 'Daniel Grenon', 'subtitle': '1ère circonscription de l’Yonne - 40,40\xa0% Sortant', 'description': 'Daniel Grenon n’aime que l’on dise qu’il tient des propos racistes. À l’issue d’un débat avec son adversaire de gauche au second tour, le député RN a contesté avoir prononcé les mots suivants : « Le Maghrébin binational, il a sa place en France. Il l’a. Mais pas dans les hauts lieux, je ne pense pas. On a besoin de protéger la France.\xa0» Problème\xa0: le journal L’Yonne républicaine\xa0dispose de l’enregistrement de l’échange, qui dément le démenti du candidat.'}
# {'category': 'Essonne', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/02/vega.jpg', 'name': 'Thiebauld Vega', 'subtitle': '1ère circonscription de l’Essonne - 22,34\xa0%', 'description': 'Obsédé par les musulmans et le porc, il propose en août 2016 de déposer du «\xa0cochon dans les mosquées\xa0». À la même période, il commente une photo de cochons au milieu de baigneuses avec ce message\xa0:«\xa0En corse pour arrêter le burkini de nouveaux mettre nageurs ont été embauché [sic]... [emojis mort de rire et tête de cochon] vive la Corse\xa0!!!\xa0»'}
# {'category': 'Essonne', 'image_src': 'https://static.mediapart.fr/etmagine/default/files/2024/07/03/carbriand.jpg', 'name': 'Jérôme Carbriand', 'subtitle': '4ème circonscription de l’Essonne - 31,03\xa0%', 'description': 'De 2012 à 2014, le candidat RN a alimenté un blog qui transpire les années 30.\xa0«\xa0Les descendants des Aryens, eux possèdent un génie pour le courage\xa0», y écrit-il notamment en fustigeant les «\xa0pédéraste\xa0» et les «\xa0juifs nomades\xa0». «\xa0Dans un monde de plus en plus caricatural, où les pensées sont souvent raccourcies, je n’ai pas jugé utile de conserver des articles aussi complexes\xa0», a-t-il déclaré à L’Humanité, pour justifier la suppression de son site.'}
# {'category': 'Val-d’Oise', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/sicard.jpg', 'name': 'Anne Sicard', 'subtitle': '1ère circonscription du Val-d’Oise - 33,65\xa0%', 'description': 'En tête dans le Val-d’Oise après le premier tour, la candidate parachutée par le RN est aussi responsable du fond de dotation de l’Institut Iliade. Structure centrale dans la formation de générations de militants identitaires, l’organisation fondée par Jean-Yves Le Gallou accueille tout le spectre de l’extrême droite radicale pour des conférences autour du «\xa0grand remplacement\xa0».'}
# {'category': 'Val-d’Oise', 'image_src': 'https://infographics.mediapart.fr/custom-pages/candidats-rn/remy.jpg', 'name': 'Nadejda Remy', 'subtitle': '2ème circonscription du Val-d’Oise - 30,21\xa0%', 'description': 'Ancienne candidate de Debout la France (DLF), Nadedja Remy avait, d’après La Lettre, accompagné Nicolas Dupont-Aignan en 2015 à Moscou, un an après l’invasion de la Crimée. En 2021, la candidate s’était fendue d’un post sur X pour répondre au pape François, qui s’attristait du sort des migrants en Méditerranée\xa0: «\xa0Et les victimes égorgées de ces envahisseurs, il a parfois une pensée pour elles, ce #Pape François\xa0?\xa0»'}

# %% [markdown]
# ## Build dataframe from parsed data

# %%
import pandas as pd

parsed_data_df = pd.DataFrame(parsed_data)
parsed_data_df.columns = ['departement_name', 'image_src', 'candidate_name', 'candidate_score', 'description']
parsed_data_df
# Out:
#    departement_name                                          image_src  \
# 0               Ain  https://infographics.mediapart.fr/custom-pages...
# 1               Ain  https://infographics.mediapart.fr/custom-pages...
# 2             Aisne  https://infographics.mediapart.fr/custom-pages...
# 3            Allier  https://infographics.mediapart.fr/custom-pages...
# 4   Alpes-Maritimes  https://infographics.mediapart.fr/custom-pages...
# ..              ...                                                ...
# 67            Yonne  https://static.mediapart.fr/etmagine/default/f...
# 68          Essonne  https://static.mediapart.fr/etmagine/default/f...
# 69          Essonne  https://static.mediapart.fr/etmagine/default/f...
# 70       Val-d’Oise  https://infographics.mediapart.fr/custom-pages...
# 71       Val-d’Oise  https://infographics.mediapart.fr/custom-pages...
#
#        candidate_name                                    candidate_score  \
# 0   Jean-Marie Mourey  1ère circonscription de l’Ain - 39,37 % Suppléant
# 1      Jérôme Buisson    4ème circonscription de l’Ain - 46,01 % Sortant
# 2    Jocelyn Dessigny  5ème circonscription de l’Aisne - 53,07 % Sort...
# 3         Jorys Bovet  2ème circonscription de l’Allier - 34,33 % Sor...
# 4       Lionel Tivoli  2ème circonscription des Alpes-Maritimes - 48,...
# ..                ...                                                ...
# 67      Daniel Grenon  1ère circonscription de l’Yonne - 40,40 % Sortant
# 68     Thiebauld Vega        1ère circonscription de l’Essonne - 22,34 %
# 69   Jérôme Carbriand        4ème circonscription de l’Essonne - 31,03 %
# 70        Anne Sicard       1ère circonscription du Val-d’Oise - 33,65 %
# 71       Nadejda Remy       2ème circonscription du Val-d’Oise - 30,21 %
#
#                                           description
# 0   « Vive la France, vive le roi ! » Sur ses rése...
# 1   À une déclaration du député noir Carlos Marten...
# 2   Sur son compte Facebook, le député et candidat...
# 3   Le député se saisit régulièrement de faits div...
# 4   Si Lionel Tivoli fait désormais campagne avec ...
# ..                                                ...
# 67  Daniel Grenon n’aime que l’on dise qu’il tient...
# 68  Obsédé par les musulmans et le porc, il propos...
# 69  De 2012 à 2014, le candidat RN a alimenté un b...
# 70  En tête dans le Val-d’Oise après le premier to...
# 71  Ancienne candidate de Debout la France (DLF), ...
#
# [72 rows x 5 columns]

# %% [markdown]
# ## Get circo dataset

# %% [markdown]
# ### Get circo positions dataset (GEOJSON)

# %%
import geopandas as gpd

circo_coords = gpd.read_file('https://static.data.gouv.fr/resources/contours-geographiques-des-circonscriptions-legislatives/20240613-191520/circonscriptions-legislatives-p10.geojson')
circo_coords.head()
# Out:
#   codeDepartement nomDepartement codeCirconscription    nomCirconscription  \
# 0              01            Ain                0104  4ème circonscription
# 1              01            Ain                0105  5ème circonscription
# 2              01            Ain                0103  3ème circonscription
# 3              01            Ain                0102  2ème circonscription
# 4              01            Ain                0101  1ère circonscription
#
#                                             geometry
# 0  POLYGON ((4.92750 45.98000, 4.92450 45.96820, ...
# 1  POLYGON ((5.59060 45.76000, 5.59040 45.76470, ...
# 2  POLYGON ((5.58640 45.66710, 5.58730 45.65990, ...
# 3  POLYGON ((4.74920 46.00360, 4.74850 46.00200, ...
# 4  POLYGON ((5.51130 46.26450, 5.50840 46.26440, ...

# %% [markdown]
# ### create merge index on Mediapart data

# %%
def extract_circo_name(circo_and_score):
  split_text = circo_and_score.split(' ')
  return split_text[0] +' '+ split_text[1]


parsed_data_df['circo_name'] = parsed_data_df['candidate_score'].apply(extract_circo_name)
parsed_data_df['merge_index'] = parsed_data_df['departement_name'] + '-' + parsed_data_df['circo_name']
parsed_data_df['merge_index'] = parsed_data_df['merge_index'].str.replace('’', "'")
parsed_data_df.head()
# Out:
#   departement_name                                          image_src  \
# 0              Ain  https://infographics.mediapart.fr/custom-pages...
# 1              Ain  https://infographics.mediapart.fr/custom-pages...
# 2            Aisne  https://infographics.mediapart.fr/custom-pages...
# 3           Allier  https://infographics.mediapart.fr/custom-pages...
# 4  Alpes-Maritimes  https://infographics.mediapart.fr/custom-pages...
#
#       candidate_name                                    candidate_score  \
# 0  Jean-Marie Mourey  1ère circonscription de l’Ain - 39,37 % Suppléant
# 1     Jérôme Buisson    4ème circonscription de l’Ain - 46,01 % Sortant
# 2   Jocelyn Dessigny  5ème circonscription de l’Aisne - 53,07 % Sort...
# 3        Jorys Bovet  2ème circonscription de l’Allier - 34,33 % Sor...
# 4      Lionel Tivoli  2ème circonscription des Alpes-Maritimes - 48,...
#
#                                          description  \
# 0  « Vive la France, vive le roi ! » Sur ses rése...
# 1  À une déclaration du député noir Carlos Marten...
# 2  Sur son compte Facebook, le député et candidat...
# 3  Le député se saisit régulièrement de faits div...
# 4  Si Lionel Tivoli fait désormais campagne avec ...
#
#                             merge_index            circo_name
# 0              Ain-1ère circonscription  1ère circonscription
# 1              Ain-4ème circonscription  4ème circonscription
# 2            Aisne-5ème circonscription  5ème circonscription
# 3           Allier-2ème circonscription  2ème circonscription
# 4  Alpes-Maritimes-2ème circonscription  2ème circonscription

# %% [markdown]
# There is no unicity, which means we will get some duplicates, we will adress this later!

# %%
len(parsed_data_df) == len(parsed_data_df['merge_index'].unique())
# Out:
# False

# %% [markdown]
# ### Create merge index on coordinates dataset

# %%
circo_coords['merge_index'] = circo_coords['nomDepartement'] + '-' + circo_coords['nomCirconscription']

# %%
circo_coords.head()
# Out:
#   codeDepartement nomDepartement codeCirconscription    nomCirconscription  \
# 0              01            Ain                0104  4ème circonscription
# 1              01            Ain                0105  5ème circonscription
# 2              01            Ain                0103  3ème circonscription
# 3              01            Ain                0102  2ème circonscription
# 4              01            Ain                0101  1ère circonscription
#
#                                             geometry               merge_index
# 0  POLYGON ((4.92750 45.98000, 4.92450 45.96820, ...  Ain-4ème circonscription
# 1  POLYGON ((5.59060 45.76000, 5.59040 45.76470, ...  Ain-5ème circonscription
# 2  POLYGON ((5.58640 45.66710, 5.58730 45.65990, ...  Ain-3ème circonscription
# 3  POLYGON ((4.74920 46.00360, 4.74850 46.00200, ...  Ain-2ème circonscription
# 4  POLYGON ((5.51130 46.26450, 5.50840 46.26440, ...  Ain-1ère circonscription

# %%
circo_coords[circo_coords.nomDepartement.str.contains('Or')]
# Out:
#     codeDepartement       nomDepartement codeCirconscription  \
# 84               21            Côte-d'Or                2105
# 85               21            Côte-d'Or                2104
# 86               21            Côte-d'Or                2101
# 87               21            Côte-d'Or                2103
# 88               21            Côte-d'Or                2102
# 302              61                 Orne                6101
# 303              61                 Orne                6103
# 304              61                 Orne                6102
# 330              66  Pyrénées-Orientales                6604
# 331              66  Pyrénées-Orientales                6602
# 332              66  Pyrénées-Orientales                6603
# 333              66  Pyrénées-Orientales                6601
#
#        nomCirconscription                                           geometry  \
# 84   5ème circonscription  MULTIPOLYGON (((5.17610 47.15360, 5.17170 47.1...
# 85   4ème circonscription  POLYGON ((4.29280 47.92590, 4.29670 47.92300, ...
# 86   1ère circonscription  POLYGON ((4.84180 47.27890, 4.84780 47.27920, ...
# 87   3ème circonscription  POLYGON ((5.25560 47.17600, 5.25960 47.17840, ...
# 88   2ème circonscription  POLYGON ((5.25560 47.17600, 5.25770 47.17550, ...
# 302  1ère circonscription  POLYGON ((-0.86030 48.50150, -0.85880 48.50040...
# 303  3ème circonscription  POLYGON ((-0.84120 48.75240, -0.84230 48.75130...
# 304  2ème circonscription  POLYGON ((0.06360 48.91670, 0.06480 48.91650, ...
# 330  4ème circonscription  POLYGON ((2.93280 42.47440, 2.93480 42.47440, ...
# 331  2ème circonscription  POLYGON ((2.32290 42.70810, 2.33170 42.70760, ...
# 332  3ème circonscription  POLYGON ((1.78610 42.57370, 1.78490 42.57230, ...
# 333  1ère circonscription  POLYGON ((2.92970 42.65370, 2.92530 42.65700, ...
#
#                                   merge_index
# 84             Côte-d'Or-5ème circonscription
# 85             Côte-d'Or-4ème circonscription
# 86             Côte-d'Or-1ère circonscription
# 87             Côte-d'Or-3ème circonscription
# 88             Côte-d'Or-2ème circonscription
# 302                 Orne-1ère circonscription
# 303                 Orne-3ème circonscription
# 304                 Orne-2ème circonscription
# 330  Pyrénées-Orientales-4ème circonscription
# 331  Pyrénées-Orientales-2ème circonscription
# 332  Pyrénées-Orientales-3ème circonscription
# 333  Pyrénées-Orientales-1ère circonscription

# %%
# 'Côte-d'Or-4ème circonscription' == 'Côte-d’Or-4ème circonscription'

# %% [markdown]
# ### add candidate info to mediapart info

# %%
circo_dataset = pd.merge(parsed_data_df, circo_coords, on='merge_index', how='left')

# %% [markdown]
# Check merge errors: nothing to declare.

# %%
circo_dataset[circo_dataset['codeCirconscription'].isnull()]
# Out:
# Empty DataFrame
# Columns: [departement_name, image_src, candidate_name, candidate_score, description, merge_index, circo_name, codeDepartement, nomDepartement, codeCirconscription, nomCirconscription, geometry]
# Index: []

# %% [markdown]
# ## Add info to leaflet map!

# %%
# Simplify the process and ensure GeoJSON structure

import folium
from shapely.geometry import shape
import json

# Initialize a map centered around France
m = folium.Map(location=[46.603354, 1.888334], zoom_start=6)

# Function to create tooltip
# Function to create tooltip
def create_tooltip(row):
    tooltip_html = f"""
    <div style="width: 200px; white-space: normal; word-wrap: break-word;">
        <img src="{row['image_src']}" alt="Candidate Image" style="width:100%; height:auto;">
        <h4>{row['candidate_name']}</h4>
        <h5>{row['candidate_score']}</h5>
        <p>{row['description']}</p>
        <p style="color:gray;">{row['nomDepartement']} - {row['nomCirconscription']}</p>
    </div>
    """
    return tooltip_html

# Add markers to the map
for _, row in circo_dataset.iterrows():

    geojson = row['geometry']

    # Add the GeoJSON object to the map
    folium.GeoJson(
        geojson,
        tooltip=folium.Tooltip(create_tooltip(row)),
        popup=folium.Popup(create_tooltip(row), max_width=300)
    ).add_to(m)

# Save the map to an HTML file
map_file_path = 'candidates_map.html'
m.save(map_file_path)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd367e6522719343b2cbc2422c2491f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd367e6522719343b2cbc2422c2491f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd367e6522719343b2cbc2422c2491f5 = L.map(
#                 &quot;map_bd367e6522719343b2cbc2422c2491f5&quot;,
#                 {
#                     center: [46.603354, 1.888334],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_68efeafe45eb91b9e7b8ae7157232676 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bd367e6522719343b2cbc2422c2491f5);
#
#
#
#         function geo_json_26008bd326c057c384cef4f52dcc35ee_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_26008bd326c057c384cef4f52dcc35ee = L.geoJson(null, {
#                 onEachFeature: geo_json_26008bd326c057c384cef4f52dcc35ee_onEachFeature,
#
#         });
#
#         function geo_json_26008bd326c057c384cef4f52dcc35ee_add (data) {
#             geo_json_26008bd326c057c384cef4f52dcc35ee
#                 .addData(data)
#                 .addTo(map_bd367e6522719343b2cbc2422c2491f5);
#         }
241], [5.3135, 46.4256], [5.319, 46.4276], [5.3228, 46.4273], [5.3246, 46.4285], [5.3225, 46.4299], [5.3196, 46.4305], [5.318, 46.4326], [5.3176, 46.4375], [5.315, 46.4406], [5.3142, 46.4427], [5.3145, 46.4456], [5.3114, 46.4459], [5.3106, 46.4469], [5.3066, 46.4454], [5.3052, 46.4467], [5.301, 46.4469], [5.2921, 46.45], [5.2895, 46.4496], [5.2861, 46.4465], [5.2838, 46.4456], [5.2812, 46.4473], [5.2793, 46.447], [5.2698, 46.4501], [5.265, 46.4514], [5.2584, 46.4499], [5.2564, 46.4507], [5.2552, 46.4553], [5.2517, 46.4563], [5.2483, 46.4581], [5.248, 46.4591], [5.2418, 46.4612], [5.238, 46.4593], [5.2366, 46.4578], [5.2348, 46.4582], [5.2318, 46.4628], [5.225, 46.4687], [5.2213, 46.4691], [5.22, 46.4681], [5.2155, 46.4684], [5.2159, 46.472], [5.2138, 46.4746], [5.2129, 46.4776], [5.2099, 46.479], [5.2114, 46.4808], [5.2133, 46.4811], [5.2142, 46.4837], [5.2134, 46.4847], [5.2108, 46.485], [5.2081, 46.4864], [5.2061, 46.4865], [5.2063, 46.4898], [5.2101, 46.4905], [5.2103, 46.4929], [5.2077, 46.4927], [5.20

# %% [markdown]
# ## Solve for multiple people for a single circo
#
# We display side-by-side in tooltip and marker.

# %%
import folium
from shapely.geometry import shape
import json
import pandas as pd
from collections import defaultdict

# Initialize a map centered around France
m = folium.Map(location=[46.603354, 1.888334], zoom_start=6)

# Function to create tooltip
def create_tooltip(row):
    tooltip_html = f"""
    <div style="flex: 1; min-width: 50%; box-sizing: border-box; padding: 5px; white-space: normal; word-wrap: break-word;">
        <img src="{row['image_src']}" alt="Candidate Image" style="width:100%; height:auto;">
        <h4>{row['candidate_name']}</h4>
        <h5>{row['candidate_score']}</h5>
        <p>{row['description']}</p>
        <p style="color:gray;">{row['nomDepartement']} - {row['nomCirconscription']}</p>
    </div>
    """
    return tooltip_html

# Group rows by their geometry to handle duplicates
grouped = circo_dataset.groupby('geometry')

for geojson, group in grouped:
    tooltip_content = ""

    # If more than one row refers to the same place, create a dual tooltip
    tooltip_content += f'<div style="display: flex; flex-wrap: wrap; width: {len(group)*200}px;">'
    for _, row in group.iterrows():
        tooltip_content += create_tooltip(row)
    tooltip_content += '</div>'

    geojson_obj = row['geometry']

    # Add the GeoJSON object to the map with combined tooltip content
    folium.GeoJson(
        geojson_obj,
        tooltip=folium.Tooltip(tooltip_content),
        popup=folium.Popup(tooltip_content, max_width=600)
    ).add_to(m)

# Save the map to an HTML file
map_file_path = 'candidates_map.html'
m.save(map_file_path)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dadece35c1f1d3eb0210fa0eea109077 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dadece35c1f1d3eb0210fa0eea109077&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dadece35c1f1d3eb0210fa0eea109077 = L.map(
#                 &quot;map_dadece35c1f1d3eb0210fa0eea109077&quot;,
#                 {
#                     center: [46.603354, 1.888334],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0f604c199a9bdbc0a03583656bae5ba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map
"Anne Sicard","Théories Conspirationnistes/Nostalgie Fasciste"
"Nadejda Remy","Théories Conspirationnistes/Nostalgie Fasciste"
"""

# %%
import io

accusation_category_df = pd.read_csv(io.StringIO(accusation_category), sep=",")
accusation_category_df
# Out:
#        candidate_name                             accusation_category
# 0   Jean-Marie Mourey                              Racisme/Xénophobie
# 1      Jérôme Buisson                              Racisme/Xénophobie
# 2    Jocelyn Dessigny                              Racisme/Xénophobie
# 3         Jorys Bovet                              Racisme/Xénophobie
# 4       Lionel Tivoli                                    Islamophobie
# ..                ...                                             ...
# 67      Daniel Grenon                              Racisme/Xénophobie
# 68     Thiebauld Vega                                    Islamophobie
# 69   Jérôme Carbriand                     Antisémitisme/Négationnisme
# 70        Anne Sicard  Théories Conspirationnistes/Nostalgie Fasciste
# 71       Nadejda Remy  Théories Conspirationnistes/Nostalgie Fasciste
#
# [72 rows x 2 columns]

# %%
circo_dataset_with_accusations = pd.merge(circo_dataset,accusation_category_df, on='candidate_name', how='left')

# %%
circo_dataset_with_accusations[circo_dataset_with_accusations['accusation_category'].isnull()]
# Out:
# Empty DataFrame
# Columns: [departement_name, image_src, candidate_name, candidate_score, description, merge_index, circo_name, codeDepartement, nomDepartement, codeCirconscription, nomCirconscription, geometry, accusation_category]
# Index: []

# %%
circo_dataset_with_accusations.accusation_category.value_counts()
# Out:
# accusation_category
# Racisme/Xénophobie                                32
# Théories Conspirationnistes/Nostalgie Fasciste    20
# Islamophobie                                       7
# Antisémitisme/Négationnisme                        7
# Sexisme/Homophobie/Violences Verbales              4
# Corruption ou Délits Financiers                    2
# Name: count, dtype: int64

# %% [markdown]
# ## Update map to color places based on accusation category and add legend

# %%
import folium
from shapely.geometry import shape
import json
import pandas as pd
from collections import defaultdict

# Initialize a map centered around France
m = folium.Map(location=[46.603354, 1.888334], zoom_start=6)

# Function to create tooltip
def create_tooltip(row):
    tooltip_html = f"""
    <div style="flex: 1; min-width: 50%; box-sizing: border-box; padding: 5px; white-space: normal; word-wrap: break-word;">
        <img src="{row['image_src']}" alt="Candidate Image" style="width:100%; height:auto;">
        <h4>{row['candidate_name']}</h4>
        <h5>{row['candidate_score']}</h5>
        <p>{row['description']}</p>
        <p style="color:gray;">{row['nomDepartement']} - {row['nomCirconscription']}</p>
    </div>
    """
    return tooltip_html

# Define color mapping for accusation categories
color_mapping = {
    'Racisme/Xénophobie': 'red',
    'Théories Conspirationnistes/Nostalgie Fasciste': 'blue',
    'Islamophobie': 'green',
    'Antisémitisme/Négationnisme': 'purple',
    'Sexisme/Homophobie/Violences Verbales': 'orange',
    'Corruption ou Délits Financiers': 'yellow'
}

# Group rows by their geometry to handle duplicates
grouped = circo_dataset_with_accusations.groupby('geometry')

for geojson, group in grouped:
    tooltip_content = ""

    # If more than one row refers to the same place, create a dual tooltip
    tooltip_content += f'<div style="display: flex; flex-wrap: wrap; width: {len(group)*200}px;">'
    for _, row in group.iterrows():
        tooltip_content += create_tooltip(row)
    tooltip_content += '</div>'

    geojson_obj = row['geometry']
    accusation_category = row['accusation_category']
    color = color_mapping.get(accusation_category, 'gray')  # Default to gray if category is not found

    # Add the GeoJSON object to the map with combined tooltip content
    folium.GeoJson(
        geojson_obj,
        tooltip=folium.Tooltip(tooltip_content),
        popup=folium.Popup(tooltip_content, max_width=600),
        style_function=lambda x, color=color: {'fillColor': color, 'color': 'black', 'weight': 1, 'fillOpacity': 0.5}
    ).add_to(m)

# Add legend to the map
legend_html = """
<div style="position: fixed;
            bottom: 50px; left: 50px; width: 300px; height: 300px;
            background-color: white; z-index:9999; font-size:14px;
            border:2px solid grey; border-radius:6px; padding: 10px;">
    <h4 style="margin-top:0;">Legende</h4>
    <p><span style="background-color: red; width: 20px; height: 20px; display: inline-block;"></span> Racisme/Xénophobie</p>
    <p><span style="background-color: blue; width: 20px; height: 20px; display: inline-block;"></span> Théories Conspirationnistes/Nostalgie Fasciste</p>
    <p><span style="background-color: green; width: 20px; height: 20px; display: inline-block;"></span> Islamophobie</p>
    <p><span style="background-color: purple; width: 20px; height: 20px; display: inline-block;"></span> Antisémitisme/Négationnisme</p>
    <p><span style="background-color: orange; width: 20px; height: 20px; display: inline-block;"></span> Sexisme/Homophobie/Violences Verbales</p>
    <p><span style="background-color: yellow; width: 20px; height: 20px; display: inline-block;"></span> Corruption ou Délits Financiers</p>
</div>
"""
m.get_root().html.add_child(folium.Element(legend_html))

# Save the map to an HTML file
map_file_path = 'candidates_map.html'
m.save(map_file_path)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fed6b911c4a2402fc421f5e9280e22c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed;
#             bottom: 50px; left: 50px; width: 300px; height: 300px;
#             background-color: white; z-index:9999; font-size:14px;
#             border:2px solid grey; border-radius:6px; padding: 10px;&quot;&gt;
#     &lt;h4 style=&quot;margin-top:0;&quot;&gt;Legende&lt;/h4&gt;
#     &lt;p&gt;&lt;span style=&quot;background-color: red; width: 20px; height: 20px; display: inline-block;&quot;&gt;&lt;/span&gt; Racisme/Xénophobie&lt;/p&gt;
#     &lt;p&gt;&lt;span style=&quot;background-color: blue; width: 20px; height: 20px; display: inline-block;&quot;&gt;&lt;/span&gt; Théories Conspirationnistes/Nostalgie Fasciste&lt;/p&gt;
#     &lt;p&gt;&lt;span style=&quot;background-color: green; width: 20px; height: 20px; display: inline-block;&quot;&gt;&lt;/span&gt; Islamophobie&lt;/p&gt;
#     &lt;p&gt;&lt;span style=&quot;background-color: purple; width: 20px; height: 20px; display: inline-block;&quot;&gt;&lt;/span&gt; Antisémitisme/Négationnisme&lt;/p&gt;
#     &lt;p&gt;&lt;span style=&quot;background-color: orange; width: 20px; height: 20px; display: inline-block;&quot;&gt;&lt;/span&gt; Sexisme/Homophobie/Violences Verbales&lt;/p&gt;
#     &lt;p&gt;&lt;span style=&quot;background-color: yellow; width: 20px; height: 20px; display: inline-block;&quot;&gt;&lt;/span&gt; Corruption ou Délits Financiers&lt;/p&gt;
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fed6b911c4a2402fc421f5e9280e22c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_